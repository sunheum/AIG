# %% [markdown]
# # 1. Mecab

# %%
# !pip install eunjeon

# %%
from eunjeon import Mecab

# %%
mecab = Mecab()

# %%
phrase1 = '경희가 인절미 $20$개, 가래떡 $12$개를 가능한 많은 접시에 똑같이 나누어 담으려고 할 때, 필요한 접시의 개수는?'
phrase2 = '자연수 x보다 작은 수 중 가장 큰 소수를 {x}로 나타내기로 할 때 3<x,y>3,5%7, {x}=31을 만족시키는 자연수 x의 개수는?'

# %%
phrase3='경희는 물 20L, 물고기 12마리를 가능한 한 많은 접시에 똑같이 나누어 담으려고 할 때, 필요한 접시의 개수는?'

# %%
phrase_chk = '10km 5kg 4시 23분 54초 23hms 3리터 7그램 5킬로그램 12킬로미터 9미터 시속 8m/s 온도 섭씨 9도 화씨 95도'

# %%
mecab.pos(phrase_chk)
# Out:
# [('10', 'SN'),
#  ('km', 'SL'),
#  ('5', 'SN'),
#  ('kg', 'SL'),
#  ('4', 'SN'),
#  ('시', 'NNBC'),
#  ('23', 'SN'),
#  ('분', 'NNBC'),
#  ('54', 'SN'),
#  ('초', 'NNBC'),
#  ('23', 'SN'),
#  ('hms', 'SL'),
#  ('3', 'SN'),
#  ('리터', 'NNBC'),
#  ('7', 'SN'),
#  ('그램', 'NNBC'),
#  ('5', 'SN'),
#  ('킬로그램', 'NNBC'),
#  ('12', 'SN'),
#  ('킬로미터', 'NNBC'),
#  ('9', 'SN'),
#  ('미터', 'NNBC'),
#  ('시속', 'NNG'),
#  ('8', 'SN'),
#  ('m', 'SL'),
#  ('/', 'SC'),
#  ('s', 'SL'),
#  ('9', 'SN'),
#  ('키', 'NNG'),
#  ('로', 'JKB'),
#  ('미터', 'NNG'),
#  ('온도', 'NNG'),
#  ('섭씨', 'NNG'),
#  ('9', 'SN'),
#  ('도', 'NNBC'),
#  ('화씨', 'NNG'),
#  ('95', 'SN'),
#  ('도', 'NNBC')]

# %%
mecab.pos(phrase2)
# Out:
# [('자연수', 'NNG'),
#  ('x', 'SL'),
#  ('보다', 'JKB'),
#  ('작', 'VA'),
#  ('은', 'ETM'),
#  ('수', 'NNB'),
#  ('중', 'NNB'),
#  ('가장', 'MAG'),
#  ('큰', 'VA+ETM'),
#  ('소수', 'NNG'),
#  ('를', 'JKO'),
#  ('{', 'SY'),
#  ('x', 'SL'),
#  ('}', 'SY'),
#  ('로', 'JKB'),
#  ('나타내', 'VV'),
#  ('기', 'ETN'),
#  ('로', 'JKB'),
#  ('할', 'VV+ETM'),
#  ('때', 'NNG'),
#  ('3', 'SN'),
#  ('<', 'SY'),
#  ('x', 'SL'),
#  (',', 'SC'),
#  ('y', 'SL'),
#  ('>', 'SY'),
#  ('3', 'SN'),
#  (',', 'SC'),
#  ('5', 'SN'),
#  ('%', 'SY'),
#  ('7', 'SN'),
#  (',', 'SC'),
#  ('{', 'SY'),
#  ('x', 'SL'),
#  ('}=', 'SY'),
#  ('31', 'SN'),
#  ('을', 'JKO'),
#  ('만족', 'NNG'),
#  ('시키', 'XSV'),
#  ('는', 'ETM'),
#  ('자연수', 'NNG'),
#  ('x', 'SL'),
#  ('의', 'JKG'),
#  ('개수', 'NNG'),
#  ('는', 'JX'),
#  ('?', 'SF')]

# %% [markdown]
# # 2. OKT( 구 twitter )

# %%
from konlpy.tag import Okt

# %%
okt = Okt()

# %%
startTime = time.time()
okt.pos(phrase1)
print(time.time()-startTime)
# Out:
# 0.0019643306732177734

# %%
okt.pos(phrase1)
# Out:
# [('경희', 'Noun'),
#  ('가', 'Josa'),
#  ('인절미', 'Noun'),
#  ('$20', 'Number'),
#  ('$', 'Punctuation'),
#  ('개', 'Noun'),
#  (',', 'Punctuation'),
#  ('가래떡', 'Noun'),
#  ('$12', 'Number'),
#  ('$', 'Punctuation'),
#  ('개', 'Noun'),
#  ('를', 'Josa'),
#  ('가능한', 'Adjective'),
#  ('많은', 'Adjective'),
#  ('접시', 'Noun'),
#  ('에', 'Josa'),
#  ('똑같이', 'Adverb'),
#  ('나누어', 'Verb'),
#  ('담으려고', 'Verb'),
#  ('할', 'Verb'),
#  ('때', 'Noun'),
#  (',', 'Punctuation'),
#  ('필요한', 'Adjective'),
#  ('접시', 'Noun'),
#  ('의', 'Josa'),
#  ('개수', 'Noun'),
#  ('는', 'Josa'),
#  ('?', 'Punctuation')]

# %%
okt.pos(phrase2)
# Out:
# [('자연수', 'Noun'),
#  ('$x', 'CashTag'),
#  ('$', 'Punctuation'),
#  ('보다', 'Verb'),
#  ('작은', 'Adjective'),
#  ('수', 'Noun'),
#  ('중', 'Noun'),
#  ('가장', 'Noun'),
#  ('큰', 'Verb'),
#  ('소수', 'Noun'),
#  ('를', 'Josa'),
#  ('$\\{', 'Punctuation'),
#  ('x', 'Alpha'),
#  ('\\}$', 'Punctuation'),
#  ('로', 'Noun'),
#  ('나타내기로', 'Verb'),
#  ('할', 'Verb'),
#  ('때', 'Noun'),
#  (',', 'Punctuation'),
#  ('$\\{', 'Punctuation'),
#  ('x', 'Alpha'),
#  ('\\}=', 'Punctuation'),
#  ('31', 'Number'),
#  ('$', 'Punctuation'),
#  ('을', 'Josa'),
#  ('만족', 'Noun'),
#  ('시키는', 'Verb'),
#  ('자연수', 'Noun'),
#  ('$x', 'CashTag'),
#  ('$', 'Punctuation'),
#  ('의', 'Noun'),
#  ('개수', 'Noun'),
#  ('는', 'Josa'),
#  ('?', 'Punctuation')]

# %%
okt.pos(phrase3)
# Out:
# [('경희', 'Noun'),
#  ('는', 'Josa'),
#  ('인절미', 'Noun'),
#  ('20', 'Number'),
#  ('개', 'Noun'),
#  (',', 'Punctuation'),
#  ('가래떡', 'Noun'),
#  ('12', 'Number'),
#  ('개', 'Noun'),
#  ('를', 'Josa'),
#  ('가능한', 'Adjective'),
#  ('한', 'Verb'),
#  ('많은', 'Adjective'),
#  ('접시', 'Noun'),
#  ('에', 'Josa'),
#  ('똑같이', 'Adverb'),
#  ('나누어', 'Verb'),
#  ('담으려고', 'Verb'),
#  ('할', 'Verb'),
#  ('때', 'Noun'),
#  (',', 'Punctuation'),
#  ('필요한', 'Adjective'),
#  ('접시', 'Noun'),
#  ('의', 'Josa'),
#  ('개수', 'Noun'),
#  ('는', 'Josa'),
#  ('?', 'Punctuation')]

# %% [markdown]
# # 3. Kkma

# %%
from konlpy.tag import Kkma

# %%
kkma = Kkma()

# %%
kkma.pos(phrase3)
# Out:
# [('경희', 'NNG'),
#  ('는', 'JX'),
#  ('인절미', 'NNG'),
#  ('20', 'NR'),
#  ('개', 'NNM'),
#  (',', 'SP'),
#  ('가래떡', 'NNG'),
#  ('12', 'NR'),
#  ('개', 'NNM'),
#  ('를', 'JKO'),
#  ('가능', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('한', 'NNG'),
#  ('많', 'VA'),
#  ('은', 'ETD'),
#  ('접시', 'NNG'),
#  ('에', 'JKM'),
#  ('똑같이', 'MAG'),
#  ('나누', 'VV'),
#  ('어', 'ECD'),
#  ('담', 'VV'),
#  ('으려고', 'ECD'),
#  ('하', 'VV'),
#  ('ㄹ', 'ETD'),
#  ('때', 'NNG'),
#  (',', 'SP'),
#  ('필요', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('접시', 'NNG'),
#  ('의', 'JKG'),
#  ('개수', 'NNG'),
#  ('는', 'JX'),
#  ('?', 'SF')]

# %%
kkma.pos(phrase2)
# Out:
# [('자연수', 'NNG'),
#  ('$', 'SW'),
#  ('x', 'OL'),
#  ('$', 'SW'),
#  ('보다', 'JKM'),
#  ('작', 'VA'),
#  ('은', 'ETD'),
#  ('수', 'NNB'),
#  ('중', 'NNB'),
#  ('가장', 'MAG'),
#  ('크', 'VA'),
#  ('ㄴ', 'ETD'),
#  ('소수', 'NNG'),
#  ('를', 'JKO'),
#  ('$', 'SW'),
#  ('\\', 'SW'),
#  ('{', 'SS'),
#  ('x', 'OL'),
#  ('\\', 'SW'),
#  ('}', 'SS'),
#  ('$', 'SW'),
#  ('로', 'JKM'),
#  ('나타내', 'VV'),
#  ('기로', 'ECD'),
#  ('하', 'VV'),
#  ('ㄹ', 'ETD'),
#  ('때', 'NNG'),
#  (',', 'SP'),
#  ('$', 'SW'),
#  ('\\', 'SW'),
#  ('{', 'SS'),
#  ('x', 'OL'),
#  ('\\', 'SW'),
#  ('}', 'SS'),
#  ('=', 'SW'),
#  ('31', 'NR'),
#  ('$', 'SW'),
#  ('을', 'JKO'),
#  ('만족', 'NNG'),
#  ('시키', 'XSV'),
#  ('는', 'ETD'),
#  ('자연수', 'NNG'),
#  ('$', 'SW'),
#  ('x', 'OL'),
#  ('$', 'SW'),
#  ('의', 'NNG'),
#  ('개수', 'NNG'),
#  ('는', 'JX'),
#  ('?', 'SF')]

# %% [markdown]
# # 4.Komoran

# %%
from konlpy.tag import Komoran

# %%
km = Komoran()

# %%
startTime = time.time()
km.pos(phrase1)
print(time.time()-startTime)
# Out:
# 0.0009975433349609375

# %%
km.pos(phrase2)
# Out:
# [('자연수', 'NNP'),
#  ('$', 'SW'),
#  ('x', 'SL'),
#  ('$', 'SW'),
#  ('보다', 'JKB'),
#  ('작은 수', 'NNP'),
#  ('중', 'NNB'),
#  ('가장', 'MAG'),
#  ('크', 'VA'),
#  ('ㄴ', 'ETM'),
#  ('소수', 'NNG'),
#  ('를', 'JKO'),
#  ('$', 'SW'),
#  ('\\', 'SW'),
#  ('{', 'SS'),
#  ('x', 'SL'),
#  ('\\', 'SW'),
#  ('}', 'SS'),
#  ('$', 'SW'),
#  ('로', 'JKB'),
#  ('나타내', 'VV'),
#  ('기', 'ETN'),
#  ('로', 'JKB'),
#  ('하', 'VV'),
#  ('ㄹ', 'ETM'),
#  ('때', 'NNG'),
#  (',', 'SP'),
#  ('$', 'SW'),
#  ('\\', 'SW'),
#  ('{', 'SS'),
#  ('x', 'SL'),
#  ('\\', 'SW'),
#  ('}', 'SS'),
#  ('=', 'SW'),
#  ('31', 'SN'),
#  ('$', 'SW'),
#  ('을', 'NNG'),
#  ('만족', 'NNG'),
#  ('시키', 'XSV'),
#  ('는', 'ETM'),
#  ('자연수', 'NNP'),
#  ('$', 'SW'),
#  ('x', 'SL'),
#  ('$', 'SW'),
#  ('의', 'JKG'),
#  ('개수', 'NNG'),
#  ('는', 'JX'),
#  ('?', 'SF')]

# %% [markdown]
# # 5.soynlp

# %%
# !pip install soynlp

# %%
from soynlp.tokenizer import LTokenizer

# %%
tokenizer = LTokenizer()

# %%
tokenizer.tokenize(phrase1)
# Out:
# ['경희가',
#  '인절미',
#  '$20$개,',
#  '가래떡',
#  '$12$개를',
#  '가능한',
#  '많은',
#  '접시에',
#  '똑같이',
#  '나누어',
#  '담으려고',
#  '할',
#  '때,',
#  '필요한',
#  '접시의',
#  '개수는?']

# %%
from soynlp.postagger import Dictionary
from soynlp.postagger import LRTemplateMatcher
from soynlp.postagger import LREvaluator
from soynlp.postagger import SimpleTagger
from soynlp.postagger import UnknowLRPostprocessor

# %%
pos_dict = {
    'Adverb': {'너무', '매우'}, 
    'Noun': {'너무너무너무', '아이오아이', '아이', '노래', '오', '이', '고양'},
    'Josa': {'는', '의', '이다', '입니다', '이', '이는', '를', '라', '라는'},
    'Verb': {'하는', '하다', '하고'},
    'Adjective': {'예쁜', '예쁘다'},
    'Exclamation': {'우와'}    
}

dictionary = Dictionary(pos_dict)
generator = LRTemplateMatcher(dictionary)    
evaluator = LREvaluator()
postprocessor = UnknowLRPostprocessor()
tagger = SimpleTagger(generator, evaluator, postprocessor)

sent = '너무너무너무는아이오아이의노래입니다!!'
print(tagger.tag(sent))
# Out:
# [('너무너무너무', 'Noun'), ('는', 'Josa'), ('아이오아이', 'Noun'), ('의', 'Josa'), ('노래', 'Noun'), ('입니다', 'Josa'), ('!!', None)]

# %% [markdown]
# # 6. kiwi

# %%
# !pip install kiwipiepy

# %%
from kiwipiepy import Kiwi, Option

# %%
kiwi=Kiwi()

# %%
kiwi.prepare()
# Out:
# 0

# %%
kiwi.analyze(phrase1)
# Out:
# [([('경희', 'NNP', 0, 2),
#    ('가', 'JKS', 2, 1),
#    ('인절미', 'NNG', 4, 3),
#    ('$', 'SW', 8, 1),
#    ('20', 'SN', 9, 2),
#    ('$', 'SW', 11, 1),
#    ('개', 'NNB', 12, 1),
#    (',', 'SP', 13, 1),
#    ('가래떡', 'NNG', 15, 3),
#    ('$', 'SW', 19, 1),
#    ('12', 'SN', 20, 2),
#    ('$', 'SW', 22, 1),
#    ('개', 'NNB', 23, 1),
#    ('를', 'JKO', 24, 1),
#    ('가능', 'NNG', 26, 2),
#    ('하', 'XSA', 28, 1),
#    ('ᆫ', 'ETM', 29, 0),
#    ('많', 'VA', 30, 1),
#    ('은', 'ETM', 31, 1),
#    ('접시', 'NNG', 33, 2),
#    ('에', 'JKB', 35, 1),
#    ('똑같이', 'MAG', 37, 3),
#    ('나누', 'VV', 41, 2),
#    ('어', 'EC', 43, 1),
#    ('담', 'VV', 45, 1),
#    ('으려고', 'EC', 46, 3),
#    ('하', 'VX', 50, 1),
#    ('ᆯ', 'ETM', 51, 0),
#    ('때', 'NNG', 52, 1),
#    (',', 'SP', 53, 1),
#    ('필요', 'NNG', 55, 2),
#    ('하', 'XSA', 57, 1),
#    ('ᆫ', 'ETM', 58, 0),
#    ('접시', 'NNG', 59, 2),
#    ('의', 'JKG', 61, 1),
#    ('개수', 'NNG', 63, 2),
#    ('는', 'JX', 65, 1),
#    ('?', 'SF', 66, 1)],
# ...

# %%
kiwi.analyze(phrase2)
# Out:
# [([('자연수', 'NNG', 0, 3),
#    ('$', 'SW', 4, 1),
#    ('x', 'SL', 5, 1),
#    ('$', 'SW', 6, 1),
#    ('보다', 'JKB', 7, 2),
#    ('작', 'VA', 10, 1),
#    ('은', 'ETM', 11, 1),
#    ('수', 'NNG', 13, 1),
#    ('중', 'NNB', 15, 1),
#    ('가장', 'MAG', 17, 2),
#    ('크', 'VA', 20, 1),
#    ('ᆫ', 'ETM', 21, 0),
#    ('소수', 'NNG', 22, 2),
#    ('를', 'JKO', 24, 1),
#    ('$\\', 'SW', 26, 2),
#    ('{', 'SS', 28, 1),
#    ('x', 'SL', 29, 1),
#    ('\\', 'SW', 30, 1),
#    ('}', 'SS', 31, 1),
#    ('$', 'SW', 32, 1),
#    ('로', 'JKB', 33, 1),
#    ('나타내', 'VV', 35, 3),
#    ('기', 'ETN', 38, 1),
#    ('로', 'JKB', 39, 1),
#    ('하', 'VV', 41, 1),
#    ('ᆯ', 'ETM', 42, 0),
#    ('때', 'NNG', 43, 1),
#    (',', 'SP', 44, 1),
#    ('$\\', 'SW', 46, 2),
#    ('{', 'SS', 48, 1),
#    ('x', 'SL', 49, 1),
#    ('\\', 'SW', 50, 1),
#    ('}', 'SS', 51, 1),
#    ('=', 'SW', 52, 1),
#    ('31', 'SN', 53, 2),
#    ('$', 'SW', 55, 1),
#    ('을', 'JKO', 56, 1),
#    ('만족', 'NNG', 58, 2),
# ...

# %% [markdown]
# # 속도 부하 테스트

# %%
# !pip install Tqdm

# %%
import time
import pandas as pd
from tqdm import tqdm

# %%
startTime = time.time()
time_mecab=[]
for i in tqdm(range(100000)):
    #print(i+1)
    instance=Mecab()
    result=instance.pos(phrase1)
    time_mecab.append(time.time() - startTime)
    #print(result)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 100000/100000 [05:06<00:00, 326.23it/s]

# %%
time_mecab
# Out:
# [0.009005069732666016,
#  0.014995098114013672,
#  0.021942853927612305,
#  0.027924776077270508,
#  0.034905433654785156,
#  0.03995060920715332,
#  0.0449371337890625,
#  0.04991555213928223,
#  0.05490279197692871,
#  0.06088519096374512,
#  0.06566309928894043,
#  0.07064986228942871,
#  0.07572793960571289,
#  0.08070135116577148,
#  0.08669304847717285,
#  0.09163713455200195,
#  0.09707236289978027,
#  0.10205817222595215,
#  0.10659527778625488,
#  0.11353516578674316,
#  0.1186063289642334,
#  0.1235661506652832,
#  0.1285543441772461,
#  0.13354134559631348,
#  0.13852596282958984,
#  0.14351224899291992,
#  0.14750361442565918,
#  0.15249037742614746,
#  0.15748238563537598,
#  0.1624612808227539,
#  0.16744780540466309,
#  0.17237639427185059,
#  0.17742371559143066,
#  0.18240785598754883,
#  0.18639779090881348,
#  0.19138407707214355,
#  0.19637060165405273,
#  0.20135831832885742,
#  0.2063448429107666,
#  0.2113327980041504,
#  0.2173151969909668,
# ...

# %%
tt = {'time_mecab' : time_mecab,
     'time_okt' : time_okt,
     'time_kkma' : time_kkma}

# %%
time_total = pd.DataFrame(tt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-1ab1783152ae> in <module>
# ----> 1 time_total = pd.DataFrame(tt)
#
# NameError: name 'tt' is not defined

# %%
time_total.to_csv('time_total.csv')

# %%
startTime = time.time()
time_okt=[]
for i in tqdm(range(100000)):
    #print(i+1)
    instance=Okt()
    result=instance.pos(phrase1)
    time_okt.append(time.time() - startTime)
    #print(result)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 100000/100000 [02:57<00:00, 562.14it/s]

# %%
time_okt
# Out:
# [0.024932146072387695,
#  0.03789782524108887,
#  0.04886817932128906,
#  0.05684709548950195,
#  0.06482553482055664,
#  0.07280898094177246,
#  0.07878661155700684,
#  0.08377504348754883,
#  0.08876156806945801,
#  0.09474587440490723,
#  0.09873485565185547,
#  0.10372138023376465,
#  0.10870862007141113,
#  0.11269760131835938,
#  0.11668682098388672,
#  0.121673583984375,
#  0.12566304206848145,
#  0.1296522617340088,
#  0.13364148139953613,
#  0.13663363456726074,
#  0.14066576957702637,
#  0.14461231231689453,
#  0.14760398864746094,
#  0.15159344673156738,
#  0.154585599899292,
#  0.15857458114624023,
#  0.16156673431396484,
#  0.16455864906311035,
#  0.16755056381225586,
#  0.1715402603149414,
#  0.1745319366455078,
#  0.17752385139465332,
#  0.18051624298095703,
#  0.18350839614868164,
#  0.18650078773498535,
#  0.1904895305633545,
#  0.1934812068939209,
#  0.1964735984802246,
#  0.19946575164794922,
#  0.20345473289489746,
#  0.20644664764404297,
#  0.21143364906311035,
# ...

# %%
startTime = time.time()
time_kkma=[]
for i in tqdm(range(100000)):
    #print(i+1)
    instance=Kkma()
    result=instance.pos(phrase1)
    time_kkma.append(time.time() - startTime)
    #print(result)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 100000/100000 [16:13<00:00, 102.67it/s]

# %%
time_kkma
# Out:
# [4.536348581314087,
#  4.561256647109985,
#  4.583239316940308,
#  4.603186845779419,
#  4.623092174530029,
#  4.641042709350586,
#  4.662984371185303,
#  4.681958436965942,
#  4.699886798858643,
#  4.717884540557861,
#  4.735788583755493,
#  4.753742456436157,
#  4.788646936416626,
#  4.8056018352508545,
#  4.8195641040802,
#  4.832529544830322,
#  4.8445398807525635,
#  4.8575098514556885,
#  4.870471000671387,
#  4.882440090179443,
#  4.894406795501709,
#  4.90537691116333,
#  4.917346239089966,
#  4.928316354751587,
#  4.940284490585327,
#  4.956246614456177,
#  4.967211723327637,
#  4.979179382324219,
#  4.991148471832275,
#  5.002122402191162,
#  5.013090133666992,
#  5.024060249328613,
#  5.036027431488037,
#  5.047953844070435,
#  5.058966636657715,
#  5.069894313812256,
#  5.082895517349243,
#  5.094828844070435,
#  5.113779067993164,
#  5.124791383743286,
#  5.136758327484131,
#  5.147729158401489,
#  5.15766167640686,
#  5.167636156082153,
#  5.178645849227905,
# ...

# %%
# 딱봐도 너무느림 의미없음!!

startTime = time.time()
time_kiwi=[]
for i in tqdm(range(100000)):
    #print(i+1)
    instance=Kiwi()
    instance.prepare()
    result=instance.analyze(phrase1)
    time_kiwi.append(time.time() - startTime)
    #print(result)
# Out:
#   0%|                                                                           | 95/100000 [01:34<27:39:40,  1.00it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-1f39a48bc142> in <module>
#       5     instance=Kiwi()
#       6     instance.prepare()
# ----> 7     result=instance.analyze(phrase1)
#       8     time_kiwi.append(time.time() - startTime)
#       9     #print(result)
#
# KeyboardInterrupt:

# %% [markdown]
# ## komoran은 5번만에 outofmemory

# %% [markdown]
# # 인스턴스 1개 ,iteration 100000

# %%
startTime = time.time()
time_komoran=[]
instance=Komoran()
for i in tqdm(range(100000)):
    #print(i+1)
    
    result=instance.pos(phrase1)
    time_komoran.append(time.time() - startTime)
    #print(result)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 100000/100000 [01:24<00:00, 1190.35it/s]

# %%
time_komoran
# Out:
# [0.9604277610778809,
#  0.9614250659942627,
#  0.9624228477478027,
#  0.9644169807434082,
#  0.96541428565979,
#  0.9674098491668701,
#  0.9694039821624756,
#  0.9713983535766602,
#  0.972395658493042,
#  0.9733929634094238,
#  0.9743902683258057,
#  0.9763851165771484,
#  0.9773821830749512,
#  0.978379487991333,
#  0.9803891181945801,
#  0.9813921451568604,
#  0.9823751449584961,
#  0.9833664894104004,
#  0.985360860824585,
#  0.9863591194152832,
#  0.9873559474945068,
#  0.9883530139923096,
#  0.9903473854064941,
#  0.9917263984680176,
#  0.9933395385742188,
#  0.9943370819091797,
#  0.9953343868255615,
#  0.9963316917419434,
#  0.9973287582397461,
#  0.9983267784118652,
#  0.9993236064910889,
#  1.0003209114074707,
#  1.0013184547424316,
#  1.0023157596588135,
#  1.0033130645751953,
#  1.0043106079101562,
#  1.00630521774292,
#  1.0073022842407227,
#  1.00830078125,
#  1.0102946758270264,
#  1.012289047241211,
#  1.0132861137390137,
#  1.014284372329712,
#  1.0152812004089355,
# ...

# %%
startTime = time.time()
time_mecab_2=[]
instance=Mecab()
for i in tqdm(range(100000)):
    #print(i+1)
    
    result=instance.pos(phrase1)
    time_mecab_2.append(time.time() - startTime)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 100000/100000 [00:05<00:00, 16942.27it/s]

# %%
startTime = time.time()
time_okt_2=[]
instance=Okt()
for i in tqdm(range(100000)):
    #print(i+1)
    
    result=instance.pos(phrase1)
    time_okt_2.append(time.time() - startTime)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 100000/100000 [02:17<00:00, 726.16it/s]

# %%
# 너무느림 의미없음!!
startTime = time.time()
time_kkma_2=[]
instance=Kkma()
for i in tqdm(range(100000)):
    #print(i+1)
    
    result=instance.pos(phrase1)
    time_kkma_2.append(time.time() - startTime)
# Out:
#  35%|█████████████████████████▉                                                 | 34598/100000 [28:47<54:24, 20.03it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-29e47870dbf7> in <module>
#       5     #print(i+1)
#       6
# ----> 7     result=instance.pos(phrase1)
#       8     time_kkma_2.append(time.time() - startTime)
#
# ~\anaconda3\envs\myenv\lib\site-packages\konlpy\tag\_kkma.py in pos(self, phrase, flatten, join)
#      53         """
#      54
# ---> 55         sentences = self.jki.morphAnalyzer(phrase)
#      56         morphemes = []
#      57         if not sentences:
#
# KeyboardInterrupt:

# %%
startTime = time.time()
time_kiwi_2=[]
instance=Kiwi()
instance.prepare()
for i in tqdm(range(100000)):
    #print(i+1)
    
    result=instance.analyze(phrase1)
    time_kiwi_2.append(time.time() - startTime)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 100000/100000 [01:34<00:00, 1053.40it/s]

# %%
time_kiwi_2
# Out:
# [0.9185447692871094,
#  0.9195427894592285,
#  0.9205622673034668,
#  0.9215366840362549,
#  0.9225368499755859,
#  0.9235305786132812,
#  0.9245283603668213,
#  0.9255266189575195,
#  0.9265270233154297,
#  0.9275228977203369,
#  0.9285182952880859,
#  0.9295148849487305,
#  0.9304702281951904,
#  0.9315097332000732,
#  0.9315097332000732,
#  0.932506799697876,
#  0.9335043430328369,
#  0.9354574680328369,
#  0.9364542961120605,
#  0.9364542961120605,
#  0.9374516010284424,
#  0.9384491443634033,
#  0.9404442310333252,
#  0.9414420127868652,
#  0.9424805641174316,
#  0.9424805641174316,
#  0.9434809684753418,
#  0.9444713592529297,
#  0.9454724788665771,
#  0.9464726448059082,
#  0.9474716186523438,
#  0.9484357833862305,
#  0.9494643211364746,
#  0.9504611492156982,
#  0.9514572620391846,
#  0.9514572620391846,
#  0.9524562358856201,
#  0.9534094333648682,
#  0.9544508457183838,
#  0.9554035663604736,
#  0.956444501876831,
#  0.9574406147003174,
#  0.9584393501281738,
# ...

# %%
tt2 = {'time_mecab_2' : time_mecab_2,
     'time_okt_2' : time_okt_2,
     'time_komoran_2' : time_komoran,
      'time_kiwi_2' : time_kiwi_2}
time_total2 = pd.DataFrame(tt2)

# %%
time_total2
# Out:
#        time_mecab_2  time_okt_2  time_komoran_2  time_kiwi_2
# 0          0.053533    2.707852        4.036662     0.918545
# 1          0.053533    2.729792        4.041648     0.919543
# 2          0.053533    2.742743        4.045639     0.920562
# 3          0.053533    2.752715        4.048629     0.921537
# 4          0.053533    2.760696        4.051623     0.922537
# ...             ...         ...             ...          ...
# 99995      5.912379  137.713115       88.019568    95.844514
# 99996      5.912379  137.714109       88.020569    95.845508
# 99997      5.912379  137.716104       88.021521    95.846475
# 99998      5.912379  137.717112       88.021521    95.847545
# 99999      5.912379  137.718099       88.022518    95.848472
#
# [100000 rows x 4 columns]

# %%
time_total2.to_csv('time_total2.csv')

# %%
time_total = pd.read_csv('./time_total.csv')

# %%
time_total
# Out:
#        time_mecab    time_okt   time_kkma
# 0        0.009005    0.024932    4.536349
# 1        0.014995    0.037898    4.561257
# 2        0.021943    0.048868    4.583239
# 3        0.027925    0.056847    4.603187
# 4        0.034905    0.064826    4.623092
# ...           ...         ...         ...
# 99995  306.529218  177.887595  973.909620
# 99996  306.532207  177.888635  973.919596
# 99997  306.535199  177.890628  973.933557
# 99998  306.537196  177.892623  973.942532
# 99999  306.540193  177.894622  973.952510
#
# [100000 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
plt.rcParams["figure.figsize"] = (15,7)

# %%
plt.rcParams["figure.figsize"] = (18,10)
plt.title('반복횟수 10만, 인스턴스 재생성', fontsize=30)

plt.plot(time_total['time_mecab'], 'g', label='Mecab')
plt.plot(time_total['time_okt'], 'r', label='Okt')
plt.plot(time_total['time_kkma'], 'b', label='Kkma')
plt.xlabel('반복횟수',fontsize=18)
plt.ylabel('시간(s)',fontsize=18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize = 18)
plt.legend(loc='upper left',fontsize=18)
plt.grid()
plt.show()

# %%
plt.rcParams["figure.figsize"] = (18,10)
plt.title('반복횟수 10만, 인스턴스 1개', fontsize=30)

plt.plot(time_total2['time_mecab_2'], 'g', label='Mecab')
plt.plot(time_total2['time_okt_2'], 'r', label='Okt')
plt.plot(time_total2['time_komoran_2'], 'b', label='Komoran')
plt.plot(time_total2['time_kiwi_2'], 'y', label='Kiwi')
plt.xlabel('반복횟수',fontsize=18)
plt.ylabel('시간(s)',fontsize=18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize = 18)
plt.legend(loc='upper left',fontsize=18)
plt.grid()
plt.show()
